# %% [markdown]
# # tratamento
#
# Tratamento de extrato de conta-corrente Nubank e Cartão XP.

# %%
import pandas as pd
import numpy as np

from src.tratamento import *
import warnings

warnings.filterwarnings('ignore')

# %%
treat = Tratamento()
treat.tratar_dados()
df = treat.df


df.sort_values('Valor')
# Out:
#          Data     Valor                Tipo  \
# 11 2024-10-09  -9500.00  Reserva - Depósito
# 20 2024-12-11  -9371.52       PIX - Enviado
# 31 2024-12-23  -8720.00  Reserva - Depósito
# 4  2024-12-01  -7500.00  Reserva - Depósito
# 8  2024-09-02  -7157.47              Boleto
# ..        ...       ...                 ...
# 2  2024-10-02   7235.28      PIX - Recebido
# 23 2024-12-12   9371.52               False
# 10 2024-10-08  10000.00      PIX - Recebido
# 1  2024-01-02  10000.00      PIX - Recebido
# 0  2024-08-01  10000.00      PIX - Recebido
#
#                                             Descrição  flag_receita  \
# 11                                      Aplicação RDB         False
# 20  Transferência enviada pelo Pix - JULIO EMANUEL...         False
# 31                                      Aplicação RDB         False
# 4                                       Aplicação RDB         False
# 8         Pagamento de boleto efetuado - BANCO XP S/A         False
# ...
